# %%
out_dir = MODEL_FOLDER / "onnx"
infos, onnx_paths = export_all_folds_to_onnx(MODEL_FOLDER, out_dir)
# Out:
# /data6/Users/yeonjoon/micromamba/envs/pytorch/lib/python3.11/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# ...
